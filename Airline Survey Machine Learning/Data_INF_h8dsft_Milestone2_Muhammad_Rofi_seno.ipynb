# %% [markdown]
# **MODEL INFERENCE**

# %% [markdown]
# # ***1. IMPORT LIBRARY***

# %%
import pickle
import pandas as pd
import numpy as np
import random

print('LIBRARY SUCESSFULYY IMPORTED')
# Out:
# Library Berhasil Di Import

# %% [markdown]
# # ***2. IMPORT MODEL***

# %%
with open('pipe.pkl', 'rb') as file_1:
  pipe = pickle.load(file_1)
  
with open('scale_pipeline.pkl', 'rb') as file_2:
  scale_pipeline = pickle.load(file_2)
  
with open('class_pipeline.pkl', 'rb') as file_3:
  class_pipeline = pickle.load(file_3)

print('MODEL SUCESSFULLY IMPORTED')
# Out:
# MODEL SUCESSFULLY IMPORTED

# %% [markdown]
# # ***3. CREATE DUMMY DATA***

# %%
# SEED VALUE
seed_value = 500
random.seed(seed_value)
np.random.seed(seed_value)

# JUMLAH DATA POINT
n = 100

# DATA DUMMY KOLOM 'inflight_wifi_service'
inflight_wifi_service = np.round(np.random.uniform(0.00, 5.00, n), 0)

# DATA DUMMY KOLOM 'departure/arrival_time_convenient'
departure_arrival_time_convenient = np.round(np.random.uniform(0.00, 5.00, n), 0)

# DATA DUMMY KOLOM 'ease_of_online_booking'
ease_of_online_booking = np.round(np.random.uniform(0.00, 5.00, n), 0)

# DATA DUMMY KOLOM 'gate_location'
gate_location = np.round(np.random.uniform(1.00, 5.00, n), 0)

# DATA DUMMY KOLOM 'food_and_drink'
food_and_drink = np.round(np.random.uniform(0.00, 5.00, n), 0)

# DATA DUMMY KOLOM 'online_boarding'
online_boarding = np.round(np.random.uniform(0.00, 5.00, n), 0)

# DATA DUMMY KOLOM 'seat_comfort'
seat_comfort = np.round(np.random.uniform(1.00, 5.00, n), 0)

# DATA DUMMY KOLOM 'inflight_entertainment'
inflight_entertainment = np.round(np.random.uniform(0.00, 5.00, n), 0)

# DATA DUMMY KOLOM 'on_board_service'
on_board_service = np.round(np.random.uniform(0.00, 5.00, n), 0)

# DATA DUMMY KOLOM 'leg_room_service'
leg_room_service = np.round(np.random.uniform(0.00, 5.00, n), 0)

# DATA DUMMY KOLOM 'baggage_handling'
baggage_handling = np.round(np.random.uniform(1.00, 5.00, n), 0)

# DATA DUMMY KOLOM 'checkin_service'
checkin_service = np.round(np.random.uniform(1.00, 5.00, n), 0)

# DATA DUMMY KOLOM 'inflight_service'
inflight_service = np.round(np.random.uniform(0.00, 5.00, n), 0)

# DATA DUMMY KOLOM 'cleanliness'
cleanliness = np.round(np.random.uniform(0.00, 5.00, n), 0)

# DATA DUMMY KOLOM 'age'
age = np.round(np.random.uniform(7.00, 85.00, n), 0)

# DATA DUMMY KOLOM 'flight_distance'
flight_distance = np.round(np.random.uniform(31.00, 4983.00, n), 0)

# DATA DUMMY KOLOM 'departure_delay_in_minutes'
departure_delay_in_minutes = np.round(np.random.uniform(0.00, 1128.00, n), 0)

# DATA DUMMY KOLOM 'arrival_delay_in_minutes'
arrival_delay_in_minutes = np.round(np.random.uniform(0.00, 1115.00, n), 0)

# MAKE DATAFRAME
data_inf = pd.DataFrame({
    'age': age,
    'flight_distance': flight_distance,
    'inflight_wifi_service': inflight_wifi_service,
    'departure_arrival_time_convenient': departure_arrival_time_convenient,
    'ease_of_online_booking': ease_of_online_booking,
    'gate_location': gate_location,
    'food_and_drink': food_and_drink,
    'online_boarding'   : online_boarding,
    'seat_comfort'    : seat_comfort,
    'inflight_entertainment'    : inflight_entertainment,
    'on_board_service'    : on_board_service,
    'leg_room_service'    : leg_room_service,
    'baggage_handling'    : baggage_handling,
    'checkin_service'    : checkin_service,
    'inflight_service'    : inflight_service,
    'cleanliness'    : cleanliness,
    'departure_delay_in_minutes'    : departure_delay_in_minutes,
    'arrival_delay_in_minutes'    : arrival_delay_in_minutes
})

# %%
data_inf
# Out:
#      age  flight_distance  inflight_wifi_service  \
# 0   77.0           2218.0                    3.0
# 1   81.0           3782.0                    0.0
# 2   63.0           1797.0                    3.0
# 3    9.0           3887.0                    3.0
# 4   32.0           2724.0                    0.0
# ..   ...              ...                    ...
# 95  81.0           3960.0                    4.0
# 96  52.0           2707.0                    3.0
# 97  44.0           3161.0                    1.0
# 98   7.0           4746.0                    2.0
# 99  16.0           4158.0                    4.0
#
#     departure_arrival_time_convenient  ease_of_online_booking  gate_location  \
# 0                                 3.0                     2.0            5.0
# 1                                 4.0                     4.0            1.0
# 2                                 4.0                     2.0            4.0
# ...

# %%
data_inf2 = data_inf.copy()
data_inf2
# Out:
#      age  flight_distance  inflight_wifi_service  \
# 0   77.0           2218.0                    3.0
# 1   81.0           3782.0                    0.0
# 2   63.0           1797.0                    3.0
# 3    9.0           3887.0                    3.0
# 4   32.0           2724.0                    0.0
# ..   ...              ...                    ...
# 95  81.0           3960.0                    4.0
# 96  52.0           2707.0                    3.0
# 97  44.0           3161.0                    1.0
# 98   7.0           4746.0                    2.0
# 99  16.0           4158.0                    4.0
#
#     departure_arrival_time_convenient  ease_of_online_booking  gate_location  \
# 0                                 3.0                     2.0            5.0
# 1                                 4.0                     4.0            1.0
# 2                                 4.0                     2.0            4.0
# ...

# %% [markdown]
# # ***5. SCALING***

# %%
data_inf_pipe = scale_pipeline.transform(data_inf)
data_inf_pipe=pd.DataFrame(data_inf_pipe)
data_inf_pipe
# Out:
#           0         1         2         3         4         5         6   \
# 0   1.351591 -0.431181  0.101885  0.331587 -0.253336  1.753033  0.985036
# 1   1.523769  0.619087 -1.935821  1.037090  1.116046 -1.667520  0.332694
# 2   0.748971 -0.713893  0.101885  1.037090 -0.253336  0.897895 -0.319648
# 3  -1.575422  0.689598  0.101885  0.331587 -0.938026 -0.812381 -1.624331
# 4  -0.585403 -0.091388 -1.935821 -1.079420 -1.622717  0.897895  0.985036
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  1.523769  0.738619  0.781121 -0.373917  0.431355  0.042757 -0.971990
# 96  0.275484 -0.102804  0.101885 -0.373917 -0.253336  0.897895  0.985036
# 97 -0.068871  0.202069 -1.256586 -1.784924 -1.622717  0.897895  0.332694
# 98 -1.661510  1.266439 -0.577350  1.037090 -0.253336 -1.667520  1.637378
# 99 -1.274112  0.871581  0.781121 -1.784924 -0.938026  0.042757  0.332694
#
#           7         8         9         10        11        12        13  \
# ...

# %%
class_pipeline.fit(data_inf)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\Hacktiv8\Phase1\Milestone\Refrence\Data_INF_h8dsft_Milestone2_Muhammad_Rofi_seno.ipynb Cell 12 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/Hacktiv8/Phase1/Milestone/Refrence/Data_INF_h8dsft_Milestone2_Muhammad_Rofi_seno.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> class_pipeline.fit(data_inf)
#
# File c:\Users\ticke\miniconda3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# ...

# %% [markdown]
# # ***6. MAKE PREDICTION TABLE***

# %%
# MEMBUAT PREDIKSI 
y_pred_inf = class_pipeline.predict(data_inf_pipe)

# MEMBUAT KOLOM PREDIKSI DAN DI CONCATE
y_pred_inf_df = pd.DataFrame(y_pred_inf, columns=['Prediction'])
tabel_inference = pd.concat([data_inf2, y_pred_inf_df], axis=1)
tabel_inference
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# d:\Hacktiv8\Phase1\Milestone\Refrence\Data_INF_h8dsft_Milestone2_Muhammad_Rofi_seno.ipynb Cell 13 line 2
#       <a href='vscode-notebook-cell:/d%3A/Hacktiv8/Phase1/Milestone/Refrence/Data_INF_h8dsft_Milestone2_Muhammad_Rofi_seno.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> # MEMBUAT PREDIKSI
# ----> <a href='vscode-notebook-cell:/d%3A/Hacktiv8/Phase1/Milestone/Refrence/Data_INF_h8dsft_Milestone2_Muhammad_Rofi_seno.ipynb#X22sZmlsZQ%3D%3D?line=1'>2</a> y_pred_inf = class_pipeline.predict(data_inf_pipe)
#       <a href='vscode-notebook-cell:/d%3A/Hacktiv8/Phase1/Milestone/Refrence/Data_INF_h8dsft_Milestone2_Muhammad_Rofi_seno.ipynb#X22sZmlsZQ%3D%3D?line=3'>4</a> # MEMBUAT KOLOM PREDIKSI DAN DI CONCATE
# ...
